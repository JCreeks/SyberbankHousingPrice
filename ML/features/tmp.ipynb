# %%
import pandas as pd

# %%
train = pd.read_csv('../../input/train_lat_lon.csv')
test = pd.read_csv('../../input/test_lat_lon.csv')
train['sub_area'] = pd.read_csv('../../input/train.csv')['sub_area']
test['sub_area'] = pd.read_csv('../../input/test.csv')['sub_area']

# %%
# tmp=pd.concat([train[['id','lat','lon','id']],test[['id','lat','lon','id']]])
# tmp.columns=['no','latitude','longitude','id']

# %%
tmp=pd.concat([train[['id','lat','lon','sub_area']],test[['id','lat','lon','sub_area']]])
tmp.columns=['no','latitude','longitude','sub_area']

# %%
tmp.shape
# Out:
# (38133, 4)

# %%
tmp.to_csv('../../input/Subarea_Longitud_Latitud.csv')

# %%
import data_utils

# %%
train, test, macro = data_utils.load_data()

# %%
train.head()
# Out:
#    timestamp  full_sq  life_sq  floor  max_floor  material   build_year  \
# 0 2011-08-20     43.0     27.0    4.0  12.131274       1.0  1986.120372
# 1 2011-08-23     34.0     19.0    3.0  12.131274       1.0  1986.120372
# 2 2011-08-27     43.0     29.0    2.0  12.131274       1.0  1986.120372
# 3 2011-09-01     89.0     50.0    9.0  12.131274       1.0  1986.120372
# 4 2011-09-05     77.0     77.0    4.0  12.131274       1.0  1986.120372
#
#    num_room  kitch_sq  state    ...     sport_count_5000_density_dis  \
# 0       2.0  7.824574   -1.0    ...                              8.0
# 1       2.0  7.824574   -1.0    ...                              7.0
# 2       2.0  7.824574   -1.0    ...                             14.0
# 3       2.0  7.824574   -1.0    ...                              2.0
# 4       2.0  7.824574   -1.0    ...                             23.0
#
#   office_count_3000_density_dis  trc_count_5000_density_dis  \
# ...

# %%
test.head()
# Out:
#        timestamp  full_sq    life_sq  floor  max_floor  material   build_year  \
# 28988 2015-07-01     39.0  20.700000    2.0        9.0       1.0  1998.000000
# 28989 2015-07-01     79.2  30.965197    8.0       17.0       1.0  1986.120372
# 28990 2015-07-01     40.5  25.100000    3.0        5.0       2.0  1960.000000
# 28991 2015-07-01     62.8  36.000000   17.0       17.0       1.0  2016.000000
# 28992 2015-07-01     40.0  40.000000   17.0       17.0       1.0  1986.120372
#
#        num_room  kitch_sq  state ... mosque_count_5000_density_dis  \
# 28988       1.0  8.900000    3.0 ...                           0.0
# 28989       3.0  7.824574    1.0 ...                           0.0
# 28990       2.0  4.800000    2.0 ...                           0.0
# 28991       2.0  7.824574    3.0 ...                           0.0
# 28992       1.0  7.824574    1.0 ...                           0.0
#
#       sport_count_5000_density_dis  office_count_3000_density_dis  \
# ...

# %%
pd.read_csv("../../input/Subarea_Longitud_Latitud.csv")
# Out:
#        Unnamed: 0     no   latitude  longitude     id
# 0               0  11054  55.682829  37.416212  11054
# 1               1  19359  55.682829  37.416212  19359
# 2               2  21535  55.682829  37.416212  21535
# 3               3  23401  55.682829  37.416212  23401
# 4               4  23613  55.682829  37.416212  23613
# 5               5  24349  55.682829  37.416212  24349
# 6               6  25055  55.682829  37.416212  25055
# 7               7  25476  55.682829  37.416212  25476
# 8               8  25576  55.682829  37.416212  25576
# 9               9  25761  55.682829  37.416212  25761
# 10             10  26250  55.682829  37.416212  26250
# 11             11  27304  55.682829  37.416212  27304
# 12             12  27404  55.682829  37.416212  27404
# 13             13  27932  55.682829  37.416212  27932
# 14             14  28177  55.682829  37.416212  28177
# 15             15  29210  55.682829  37.416212  29210
# ...

# %%
#delete_features = pd.read_table("../../cols_to_drop.txt").iloc[1:62]
    
    #tmp=list(pd.read_table("../../cols_to_drop.txt").iloc[1:62])
    #delete_features = list(set().union(delete_features,tmp))
